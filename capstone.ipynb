# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\radhmenon'

# %%
os.chdir('C:/Users/radhmenon/Downloads/Capstone3_CarsData (2)/Capstone3_CarsData/Car_sales_datasets_P3')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\radhmenon\\Downloads\\Capstone3_CarsData (2)\\Capstone3_CarsData\\Car_sales_datasets_P3'

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Car_sales_details_p3.csv')
data1 = pd.read_csv('sales_Status_p3.csv')

# %%
data.head()
#data['name'].unique().shape
# Out:
#    Sales_ID                          name  year  selling_price  km_driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power  seats
# ...

# %%
data1.head()
# Out:
#    Sales_ID sold
# 0         1    Y
# 1         2    Y
# 2         3    Y
# 3         4    Y
# 4         5    Y

# %%
data2=pd.merge(data,data1,on='Sales_ID',how='outer')
data2.head()
# Out:
#    Sales_ID                          name  year  selling_price  km_driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power  seats sold
# ...

# %%
data2[data2['sold']=='Y'].groupby('State or Province',as_index=False).agg({'name':np.size}).rename(columns={'name':'Sales'}).sort_values('Sales',ascending=False)
# Out:
#        State or Province  Sales
# 26              New York    293
# 3             California    274
# 10              Illinois    148
# 34                 Texas    138
# 38            Washington    120
# 7                Florida    118
# 31          Pennsylvania     80
# 17         Massachusetts     76
# 27        North Carolina     75
# 18              Michigan     71
# 6   District of Columbia     68
# 8                Georgia     62
# 11               Indiana     45
# 28                  Ohio     40
# 30                Oregon     30
# 12                  Iowa     30
# 33             Tennessee     29
# 16              Maryland     28
# 29              Oklahoma     27
# 2               Arkansas     27
# 13                Kansas     26
# 40             Wisconsin     25
# 19             Minnesota     25
# 35                  Utah     20
# 24            New Jersey     15
# 9                  Idaho     15
# 15                 Maine     14
# 1                Arizona     12
# ...
